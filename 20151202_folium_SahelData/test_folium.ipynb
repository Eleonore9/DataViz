# %% [markdown]
# ##Let's try out Folium library!

# %%
import folium

# %% [markdown]
# ###It's very easy to create a Leaflet.js map:

# %%
map_osm = folium.Map(location=[45.5236, -122.6750], zoom_start=15)

map_osm
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#   <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/andrewgiessel/leafletstuff/master/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_f927aa106d874a9ca4cd31dc0c73fed3&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_f927aa106d874a9ca4cd31dc0c73fed3', {
#                                        center:[45.5236, -122.675],
#                                        zoom: 15,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       /*
#       addition of the image layers
#       */
#
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    </script>
#
# </body>" style="width: 100%; height: 500px; border: none"></iframe>

# %% [markdown]
# ##Now let's look a dataset

# %%
from pandas import read_excel

import xlrd

# %%
## Severe malnutrition in Sahel - data from @hdx
df_sahel = read_excel("Sahel_Countries_SAM_Nutrition_Admin1_Summary_Latest_Surveys.xlsx")

# %%
df_sahel
# Out:
#        CNTRY_NAME CNTRY_CODE          ADM1_NAME ADM1_CODE Rowcacode1  \
# 0    Burkina Faso        BFA  Boucle du Mouhoun    BFA046     BFA046
# 1    Burkina Faso        BFA           Cascades    BFA047     BFA047
# 2    Burkina Faso        BFA             Centre    BFA013     BFA013
# 3    Burkina Faso        BFA         Centre-Est    BFA048     BFA048
# 4    Burkina Faso        BFA        Centre-Nord    BFA049     BFA049
# 5    Burkina Faso        BFA       Centre-Ouest    BFA050     BFA050
# 6    Burkina Faso        BFA         Centre-Sud    BFA051     BFA051
# 7    Burkina Faso        BFA                Est    BFA052     BFA052
# 8    Burkina Faso        BFA      Hauts-bassins    BFA053     BFA053
# 9    Burkina Faso        BFA               Nord    BFA054     BFA054
# 10   Burkina Faso        BFA    Plateau Central    BFA055     BFA055
# 11   Burkina Faso        BFA              Sahel    BFA056     BFA056
# 12   Burkina Faso        BFA          Sud-Ouest    BFA057     BFA057
# 13       Cameroon        CMR           Adamaoua    CMR001     CMR001
# 14       Cameroon        CMR             Centre    CMR002     CMR002
# 15       Cameroon        CMR                Est    CMR003     CMR003
# 16       Cameroon        CMR       Extreme-Nord    CMR004     CMR004
# 17       Cameroon        CMR           Littoral    CMR005     CMR005
# 18       Cameroon        CMR               Nord    CMR006     CMR006
# 19       Cameroon        CMR         Nord-Ouest    CMR007     CMR007
# 20       Cameroon        CMR              Ouest    CMR008     CMR008
# 21       Cameroon        CMR                Sud    CMR009     CMR009
# 22       Cameroon        CMR          Sud-Ouest    CMR010     CMR010
# 23           Chad        TCD      Barh-El-Gazel    TCD019     TCD019
# 24           Chad        TCD              Batha    TCD001     TCD001
# 25           Chad        TCD             Borkou    TCD002     TCD002
# 26           Chad        TCD     Chari Baguirmi    TCD003     TCD003
# 27           Chad        TCD         Ennedi Est    TCD020     TCD020
# 28           Chad        TCD       Ennedi Ouest    TCD023     TCD023
# 29           Chad        TCD              Guera    TCD004     TCD004
# ..            ...        ...                ...       ...        ...
# 105       Nigeria        NGA              Kebbi    NGA022     NGA022
# 106       Nigeria        NGA               Kogi    NGA023     NGA023
# 107       Nigeria        NGA              Kwara    NGA024     NGA024
# 108       Nigeria        NGA              Lagos    NGA025     NGA025
# 109       Nigeria        NGA           Nasarawa    NGA026     NGA026
# 110       Nigeria        NGA              Niger    NGA027     NGA027
# 111       Nigeria        NGA               Ogun    NGA028     NGA028
# 112       Nigeria        NGA               Ondo    NGA029     NGA029
# 113       Nigeria        NGA               Osun    NGA030     NGA030
# 114       Nigeria        NGA                Oyo    NGA031     NGA031
# 115       Nigeria        NGA            Plateau    NGA032     NGA032
# 116       Nigeria        NGA             Rivers    NGA033     NGA033
# 117       Nigeria        NGA             Sokoto    NGA034     NGA034
# 118       Nigeria        NGA             Taraba    NGA035     NGA035
# 119       Nigeria        NGA               Yobe    NGA036     NGA036
# 120       Nigeria        NGA            Zamfara    NGA037     NGA037
# 121       Senegal        SEN              Dakar    SEN001     SEN001
# 122       Senegal        SEN           Diourbel    SEN002     SEN002
# 123       Senegal        SEN             Fatick    SEN003     SEN003
# 124       Senegal        SEN           Kaffrine    SEN004     SEN004
# 125       Senegal        SEN            Kaolack    SEN005     SEN005
# 126       Senegal        SEN           Kedougou    SEN006     SEN006
# 127       Senegal        SEN              Kolda    SEN007     SEN007
# 128       Senegal        SEN              Louga    SEN008     SEN008
# 129       Senegal        SEN              Matam    SEN009     SEN009
# 130       Senegal        SEN        Saint-Louis    SEN010     SEN010
# 131       Senegal        SEN            Sedhiou    SEN011     SEN011
# 132       Senegal        SEN        Tambacounda    SEN012     SEN012
# 133       Senegal        SEN              Thies    SEN013     SEN013
# 134       Senegal        SEN         Ziguinchor    SEN014     SEN014
#
#            Season  Year                                   Survey name  \
# 0    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 1    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 2    Post-Harvest  2013                        Nutrition Survey SMART
# 3    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 4    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 5    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 6    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 7    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 8    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 9    Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 10   Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 11   Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 12   Post-Harvest  2014  Nutrition Survey SMART - Preliminary results
# 13    Lean period  2014                       Nutrition Survey SMART
# 14          Other  2011                                      EDS-MICS
# 15    Lean period  2014                        Multisectorial survey
# 16    Lean period  2014                       Nutrition Survey SMART
# 17          Other  2011                                      EDS-MICS
# 18    Lean period  2014                       Nutrition Survey SMART
# 19   Post-Harvest  2012                        Nutrition Survey SMART
# 20          Other  2011                                      EDS-MICS
# 21          Other  2011                                      EDS-MICS
# 22          Other  2011                                      EDS-MICS
# 23   Post-Harvest  2014           Nutrition Survey SMART - Sahel Band
# 24   Post-Harvest  2014           Nutrition Survey SMART - Sahel Band
# 25          Other  2010                                          MICS
# 26   Post-Harvest  2013             Nutrition Survey SMART Sahel Band
# 27          Other  2010                                          MICS
# 28          Other  2010                                          MICS
# 29   Post-Harvest  2014           Nutrition Survey SMART - Sahel Band
# ..            ...   ...                                           ...
# 105  Post-Harvest  2014                   Health and Nutrition survey
# 106  Post-Harvest  2014                   Health and Nutrition survey
# 107  Post-Harvest  2014                   Health and Nutrition survey
# 108  Post-Harvest  2014                   Health and Nutrition survey
# 109  Post-Harvest  2014                   Health and Nutrition survey
# 110  Post-Harvest  2014                   Health and Nutrition survey
# 111  Post-Harvest  2014                   Health and Nutrition survey
# 112  Post-Harvest  2014                   Health and Nutrition survey
# 113  Post-Harvest  2014                   Health and Nutrition survey
# 114  Post-Harvest  2014                   Health and Nutrition survey
# 115  Post-Harvest  2014                   Health and Nutrition survey
# 116  Post-Harvest  2014                   Health and Nutrition survey
# 117  Post-Harvest  2014                   Health and Nutrition survey
# 118  Post-Harvest  2014                   Health and Nutrition survey
# 119  Post-Harvest  2014                   Health and Nutrition survey
# 120  Post-Harvest  2014                   Health and Nutrition survey
# 121   Lean period  2014                        Nutrition Survey SMART
# 122   Lean period  2014                        Nutrition Survey SMART
# 123   Lean period  2014                        Nutrition Survey SMART
# 124   Lean period  2014                        Nutrition Survey SMART
# 125   Lean period  2014                        Nutrition Survey SMART
# 126   Lean period  2014                        Nutrition Survey SMART
# 127   Lean period  2014                        Nutrition Survey SMART
# 128   Lean period  2014                        Nutrition Survey SMART
# 129   Lean period  2014                        Nutrition Survey SMART
# 130   Lean period  2014                        Nutrition Survey SMART
# 131   Lean period  2014                        Nutrition Survey SMART
# 132   Lean period  2014                        Nutrition Survey SMART
# 133   Lean period  2014                        Nutrition Survey SMART
# 134   Lean period  2014                        Nutrition Survey SMART
#
#                                               Comments  Latest SAM Prevalence
# 0    Data collection Sept-Oct 2014 (Attention P/T a...                    1.4
# 1    Data collection Sept-Oct 2014 (Attention P/T a...                    0.2
# 2    Data collection Septembre 2013 (Attention P/T ...                    1.8
# 3    Data collection Sept-Oct 2014 (Attention P/T a...                    1.0
# 4    Data collection Sept-Oct 2014 (Attention P/T a...                    1.0
# 5    Data collection Sept-Oct 2014 (Attention P/T a...                    1.6
# 6    Data collection Sept-Oct 2014 (Attention P/T a...                    0.7
# 7    Data collection Sept-Oct 2014 (Attention P/T a...                    1.8
# 8    Data collection Sept-Oct 2014 (Attention P/T a...                    2.2
# 9    Data collection Sept-Oct 2014 (Attention P/T a...                    2.6
# 10   Data collection Sept-Oct 2014 (Attention P/T a...                    1.0
# 11   Data collection Sept-Oct 2014 (Attention P/T a...                    2.5
# 12   Data collection Sept-Oct 2014 (Attention P/T a...                    0.7
# 13                       Data collection Sept-Oct 2014                    1.5
# 14                                 Preliminary results                    0.6
# 15   Data collection June 2014.  Gado  refugee site...                    0.0
# 16                       Data collection Sept-Oct 2014                    2.0
# 17                                 Preliminary results                    0.0
# 18                       Data collection Sept-Oct 2014                    1.4
# 19           Data collection Nov-Dec 2012. Six regions                    0.7
# 20                                 Preliminary results                    0.4
# 21                                 Preliminary results                    2.9
# 22                                 Preliminary results                    0.4
# 23   Data collection Jan-Mar 2014. Ten regions and ...                    2.4
# 24   Data collection Jan-Mar 2014. Ten regions and ...                    3.9
# 25                                    Resultats finaux                   10.1
# 26   Data collection Jan-Feb 2013. 11 regions and N...                    0.2
# 27                                    Resultats finaux                   10.1
# 28                                    Resultats finaux                   10.1
# 29   Data collection Jan-Mar 2014. Ten regions and ...                    0.9
# ..                                                 ...                    ...
# 105                    Data collection Jan-Avril 2014                     1.8
# 106                    Data collection Jan-Avril 2014                     0.0
# 107                    Data collection Jan-Avril 2014                     1.0
# 108                    Data collection Jan-Avril 2014                     0.9
# 109                    Data collection Jan-Avril 2014                     0.7
# 110                    Data collection Jan-Avril 2014                     0.3
# 111                    Data collection Jan-Avril 2014                     0.2
# 112                    Data collection Jan-Avril 2014                     0.2
# 113                    Data collection Jan-Avril 2014                     0.5
# 114                    Data collection Jan-Avril 2014                     1.3
# 115                    Data collection Jan-Avril 2014                     0.0
# 116                    Data collection Jan-Avril 2014                     0.3
# 117                    Data collection Jan-Avril 2014                     1.7
# 118                    Data collection Jan-Avril 2014                     0.5
# 119                    Data collection Jan-Avril 2014                     3.1
# 120                    Data collection Jan-Avril 2014                     1.2
# 121                Data collection Juin/Juilland 2014                     0.5
# 122                Data collection Juin/Juilland 2014                     1.1
# 123                Data collection Juin/Juilland 2014                     1.1
# 124                Data collection Juin/Juilland 2014                     1.0
# 125                Data collection Juin/Juilland 2014                     1.2
# 126                Data collection Juin/Juilland 2014                     1.1
# 127                Data collection Juin/Juilland 2014                     1.2
# 128                Data collection Juin/Juilland 2014                     1.4
# 129                Data collection Juin/Juilland 2014                     3.5
# 130                Data collection Juin/Juilland 2014                     2.3
# 131                Data collection Juin/Juilland 2014                     1.4
# 132                Data collection Juin/Juilland 2014                     2.0
# 133                Data collection Juin/Juilland 2014                     0.6
# 134                Data collection Juin/Juilland 2014                     0.9
#
# [135 rows x 10 columns]
